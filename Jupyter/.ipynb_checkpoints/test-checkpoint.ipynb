# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

n = 300

m = 1 # коэффициент ускорения
fig = plt.figure(figsize=(6,4))

x = [15.993, 15.993, 14.069, 14.069, 12.145, 12.145, 12.145, 10.221, 10.221, 8.297, 8.297, 8.297, 6.372, 6.372, 4.448, 4.448, 4.448, 2.524, 2.524, 0.6, 0.6, 0.6]
y = [10.168, 5.384, 7.776, 2.992, 10.168, 5.384, 0.6, 7.776, 2.992, 10.168, 5.384, 0.6, 7.776, 2.992, 10.168, 5.384, 0.6, 7.776, 2.992, 10.168, 5.384, 0.6]


xStatic = np.linspace(0., 7, n)

def animate(i, x, y, m = 5):
    
    plt.plot(x[:i], y[:i], color='black', lw=3)
    plt.plot(x[:i], y[:i],'ro', ms=10 )
    
    plt.xlim(0, 20)
    plt.ylim(0, 15)
    plt.grid(ls='solid', lw=0.2)
    
anim = animation.FuncAnimation(fig, animate,  fargs=(x, y, m), frames=int(n/m)*10, interval=200, repeat=False)
# Out:
# <img src="data:image/png;base64,..." width="598.8889047540268">
